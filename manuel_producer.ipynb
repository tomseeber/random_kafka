# %%
import requests
from confluent_kafka import Producer
import json

KAFKA_TOPIC = 'latest_events'
KAFKA_BOOTSTRAP_SERVERS = 'broker:9092'
#REQUEST_URL = "https://stream.wikimedia.org/v2/stream/recentchange"
REQUEST_URL = "http://fact_api/fact"

# %%
def delivery_callback(err, msg):
    if err:
        print('%% Message failed delivery: %s' % err)
    else:
        print('%% Message delivered to %s [%d]' % (msg.topic(), msg.partition()))

def main():
    # Kafka producer configuration
    conf = {'bootstrap.servers': KAFKA_BOOTSTRAP_SERVERS}

    # Create Kafka producer instance
    producer = Producer(conf)

    # Read the Wikimedia stream and produce messages to Kafka
    response = requests.get(REQUEST_URL).json()
    
    
    for adict in response:
        if adict:
            message = json.dumps(adict)            
            
            # Produce message to Kafka
            producer.produce(KAFKA_TOPIC, message, callback=delivery_callback)

            # Flush messages to Kafka to ensure they are sent immediately
            producer.flush()

    # Close Kafka producer
    producer.close()

# %%
main()
# Out:
# %3|1710510477.981|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 161ms in state CONNECT)
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/dev311/lib/python3.11/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File /opt/anaconda3/envs/dev311/lib/python3.11/site-packages/urllib3/util/connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File /opt/anaconda3/envs/dev311/lib/python3.11/socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# --> 962 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     963     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File /opt/anaconda3/envs/dev311/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File /opt/anaconda3/envs/dev311/lib/python3.11/site-packages/urllib3/connectionpool.py:415, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414     else:
# --> 415         conn.request(method, url, **httplib_request_kw)
#     417 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     418 # legitimately able to close the connection after sending a valid response.
#     419 # With this behaviour, the received response is still readable.
#
# File /opt/anaconda3/envs/dev311/lib/python3.11/site-packages/urllib3/connection.py:244, in HTTPConnection.request(self, method, url, body, headers)
#     243     headers["User-Agent"] = _get_default_user_agent()
# --> 244 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File /opt/anaconda3/envs/dev311/lib/python3.11/http/client.py:1283, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1282 """Send a complete request to the server."""
# -> 1283 self._send_request(method, url, body, headers, encode_chunked)
#
# File /opt/anaconda3/envs/dev311/lib/python3.11/http/client.py:1329, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1328     body = _encode(body, 'body')
# -> 1329 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /opt/anaconda3/envs/dev311/lib/python3.11/http/client.py:1278, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1277     raise CannotSendHeader()
# -> 1278 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /opt/anaconda3/envs/dev311/lib/python3.11/http/client.py:1038, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1037 del self._buffer[:]
# -> 1038 self.send(msg)
#    1040 if message_body is not None:
#    1041
#    1042     # create a consistent interface to message_body
#
# File /opt/anaconda3/envs/dev311/lib/python3.11/http/client.py:976, in HTTPConnection.send(self, data)
#     975 if self.auto_open:
# --> 976     self.connect()
#     977 else:
#
# File /opt/anaconda3/envs/dev311/lib/python3.11/site-packages/urllib3/connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File /opt/anaconda3/envs/dev311/lib/python3.11/site-packages/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x1170f08d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File /opt/anaconda3/envs/dev311/lib/python3.11/site-packages/requests/adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#
# File /opt/anaconda3/envs/dev311/lib/python3.11/site-packages/urllib3/connectionpool.py:798, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     796     e = ProtocolError("Connection aborted.", e)
# --> 798 retries = retries.increment(
#     799     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     800 )
#     801 retries.sleep()
#
# File /opt/anaconda3/envs/dev311/lib/python3.11/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='fact_api', port=80): Max retries exceeded with url: /fact (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1170f08d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 main()
#
# Cell In[3], line 15, in main()
#      12 producer = Producer(conf)
#      14 # Read the Wikimedia stream and produce messages to Kafka
# ---> 15 response = requests.get(REQUEST_URL).json()
#      18 for adict in response:
#      19     if adict:
#
# File /opt/anaconda3/envs/dev311/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/anaconda3/envs/dev311/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/anaconda3/envs/dev311/lib/python3.11/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File /opt/anaconda3/envs/dev311/lib/python3.11/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/envs/dev311/lib/python3.11/site-packages/requests/adapters.py:520, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     516     if isinstance(e.reason, _SSLError):
#     517         # This branch is for urllib3 v1.22 and later.
#     518         raise SSLError(e, request=request)
# --> 520     raise ConnectionError(e, request=request)
#     522 except ClosedPoolError as e:
#     523     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='fact_api', port=80): Max retries exceeded with url: /fact (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1170f08d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# %3|1710510479.825|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1710510509.907|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710510539.993|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710510570.082|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710510600.167|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710510630.242|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710510660.324|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710510690.404|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710510720.505|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710510750.595|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710510781.683|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710510811.762|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710510841.845|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710510871.922|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710510903.019|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710510934.121|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710510964.203|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710510994.290|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511025.371|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710511055.448|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511085.537|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710511116.642|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710511146.737|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511176.832|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511206.931|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511237.017|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511267.101|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511297.184|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511327.268|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511357.352|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511387.429|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511417.513|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511447.595|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511477.682|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511507.754|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511538.833|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710511568.907|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 7ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511598.984|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511630.073|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710511660.159|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511691.262|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710511721.353|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511751.444|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 6ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511781.530|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511811.611|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511842.685|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710511872.772|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511902.848|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511932.940|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511963.017|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710511993.094|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512023.196|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512053.284|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512083.375|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512113.461|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 9ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512144.527|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710512175.616|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710512205.699|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512235.784|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512265.883|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 16ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512296.955|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710512328.052|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710512358.139|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512388.230|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 8ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512418.301|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512448.386|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512478.471|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512508.554|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 7ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512538.635|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512568.702|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512599.794|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710512629.875|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710512659.970|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 8ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512691.049|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710512721.134|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512751.213|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512781.282|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512811.370|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512841.463|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512871.678|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512901.908|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512932.116|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512962.322|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710512992.413|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513023.506|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710513054.588|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710513084.673|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513115.764|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710513145.844|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513175.919|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513207.009|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710513237.091|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513267.190|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513297.266|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513327.365|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513357.444|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513387.532|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513417.625|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513447.699|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513477.784|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513507.870|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513537.958|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 7ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513568.041|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513598.237|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710513629.343|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710513659.431|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513689.524|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513719.604|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513749.685|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513779.776|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513809.862|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513839.939|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513870.026|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513900.114|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710513931.207|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710513962.299|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710513992.363|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514022.438|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514052.523|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514083.613|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710514113.697|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514143.784|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514173.878|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514203.966|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514234.049|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514264.145|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514295.216|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710514325.300|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514355.380|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514385.462|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514415.544|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514446.616|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710514476.710|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514506.793|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514537.874|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710514567.971|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514599.047|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710514629.130|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514660.218|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710514691.306|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710514721.383|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514751.454|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514781.536|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514811.616|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514841.706|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514871.798|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514901.875|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514931.965|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514962.053|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710514993.139|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710515023.226|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515053.306|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515083.406|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515113.486|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515143.561|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515173.640|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515204.740|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710515235.828|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710515265.916|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 6ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515297.019|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1710515327.102|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515357.189|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515387.270|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515417.353|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515447.437|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515477.507|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515507.591|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515537.674|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515567.761|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515597.879|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515628.102|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515658.294|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515688.520|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515718.714|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515748.948|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1710515779.156|FAIL|rdkafka#producer-1| [thrd:broker:9092/bootstrap]: broker:9092/bootstrap: Failed to resolve 'broker:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 15 identical error(s) suppressed)
